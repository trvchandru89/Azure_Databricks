# %%
# %sql
create database if not exists dev.demo_db

# %%
# %sql
create database if not exists qa.demo_db

# %%
# %sql
create volume dev.demo_db.vol1;

# %%
dbutils.fs.ls(
  "/Volumes/dev/demo_db/vol1"
)

# %%
# %fs ls /Volumes/dev/demo_db/vol1

# %%
# %fs ls abfss://azdb-container-1@rvchandruazdbsa1.dfs.core.windows.net/

# %%
# %sql
select * from dev.demo_db.invoices_yearly
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
# %sql
select count(*) from dev.demo_db.invoices_yearly

# %%
_sqldf.display()
