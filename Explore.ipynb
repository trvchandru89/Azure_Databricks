# %%
# %python
dbutils.widgets.text(
    "UserName",
    "",
    "Enter your user name"
)
print(f"UserName: {dbutils.widgets.get('UserName')}")
# DBTITLE 1

# %%
print(f"Catalog Name: {spark.catalog.currentCatalog()}")
print(f"Database Name: {spark.catalog.currentDatabase()}")
print(f"Working Directory: dbfs:/mnt{dbutils.entry_point.getDbutils().notebook().getContext().notebookPath().get()}")
# DBTITLE 1

# %%
 dbutils.fs.ls("/")

# %%
# %sh
wget https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv

# %%
 dbutils.fs.ls("/")

# %%
import os
print(os.getcwd(),"Telco-Customer-Churn.csv")

# %%
# This line prints the current working directory and the CSV file name
# print(os.getcwd(),"/Telco-Customer-Churn.csv")

# Path to the Telco-Customer-Churn dataset
dataset_path = "/Workspace/Users/ramachandran.venkatraman@outlook.com/Telco-Customer-Churn.csv"

# %%
telco_df = spark.read.csv(dataset_path, header=True, inferSchema=True)
display(telco_df)

# %%
# %fs ls /home
