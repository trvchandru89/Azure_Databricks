# %%
# %sql
select * from dev.demo_db.flight_time_tbl

# %%
spark.read.format("delta").table("dev.demo_db.flight_time_tbl").display()

# %%
(spark.read.format("delta")
 .load("abfss://rvazdb-metastore@rvchandruazdbsa1.dfs.core.windows.net/ext_data")
 .display()
 )

# %% [markdown]
# create external table

# %%
# %sql
create table if not exists dev.demo_db.flight_time_tbl_ext
          (FL_DATE DATE,
            OP_CARRIER STRING,
            OP_CARRIER_FL_NUM INT,
            ORIGIN STRING,
            ORIGIN_CITY_NAME STRING,
            DEST STRING,
            DEST_CITY_NAME STRING,
            CRS_DEP_TIME INTEGER,
            DEP_TIME INTEGER,
            WHEELS_ON INTEGER,            
            TAXI_IN INTEGER,
            CRS_ARR_TIME INT,
            ARR_TIME INT,
            CANCELLED STRING,
            DISTANCE INT) USING DELTA
            LOCATION "abfss://rvazdb-metastore@rvchandruazdbsa1.dfs.core.windows.net/ext_data"

# %%
# %sql
select * from dev.demo_db.flight_time_tbl_ext
