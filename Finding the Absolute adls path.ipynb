# %%
# %sql 
describe detail dev.demo_db.people

# %%
table_details = spark.sql("describe detail dev.demo_db.people").collect()

# %%
table_details[0].location

# %%
# %sql
describe detail db_learn.default.telco_test
