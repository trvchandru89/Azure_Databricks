# %%
# %fs ls /Volumes/dev/demo_db/dlt_data

# %%
# %fs
mkdirs /Volumes/dev/demo_db/dlt_data/customers

# %%
# %fs
mkdirs /Volumes/dev/demo_db/dlt_data/invoices

# %%
# %%bash
# %fs
# cp /Volumes/dev/demo_db/dlt_data/invoices_2021.csv /Volumes/dev/demo_db/dlt_data/invoices/invoices_2021.csv

# %%
# %%bash
# %fs
# cp /Volumes/dev/demo_db/dlt_data/invoices_2022.csv /Volumes/dev/demo_db/dlt_data/invoices/invoices_2022.csv

# %%
# %%bash
# %fs
# cp /Volumes/dev/demo_db/dlt_data/customers_1.csv /Volumes/dev/demo_db/dlt_data/customers/customers_1.csv
